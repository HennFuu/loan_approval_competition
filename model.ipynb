# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from xgboost import XGBClassifier

# %%
df = pd.read_csv('./train.csv')
df = df.sort_index()
df.head()
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
# 2   2          29          28800                   OWN                8.0
# 3   3          30          70000                  RENT               14.0
# 4   4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# ...

# %% [markdown]
# # Data Handling

# %%
cat_cols = df.select_dtypes(include='object').columns.tolist()
df = pd.get_dummies(df, columns=cat_cols).astype(int)

# %%
scaler = StandardScaler()
cont_cols = df.select_dtypes(include=['int','float']).drop(columns=['id','loan_status']).columns.tolist()
df[cont_cols] = scaler.fit_transform(df[cont_cols])

# %%
df.head()
# Out:
#    id  person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0   0    1.566200      -0.765768          -1.187200  -0.578306       0.298034
# 1   1   -0.920057      -0.212128           0.328047  -0.937775       0.952660
# 2   2    0.240196      -0.929223           0.833130  -0.578306      -0.683906
# 3   3    0.405947       0.156966           2.348377   0.500101       0.298034
# 4   4   -0.920057      -0.106673          -0.682117  -0.578306      -1.338532
#
#    loan_percent_income  cb_person_cred_hist_length  loan_status  \
# 0                  0.0                    2.031798            0
# 1                  0.0                   -0.946489            0
# 2                  0.0                    1.039036            0
# 3                  0.0                   -0.201917            0
# 4                  0.0                   -0.698298            0
#
#    person_home_ownership_MORTGAGE  ...  loan_intent_VENTURE  loan_grade_A  \
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Model Training

# %%
variables = cont_cols + df.iloc[:,9:].columns.tolist()
X = df[variables]
y = df['loan_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) #0.3 e 0.01

# %%
model = LogisticRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Acurácia: {accuracy * 100:.2f}%')
# Out:
# Acurácia: 91.65%

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9516\1030253832.py in ?()
#       1 model = XGBClassifier()
# ----> 2 model.fit(X_train, y_train)
#
# c:\Users\henri\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# c:\Users\henri\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py in ?(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1508                     params["objective"] = "multi:softprob"
# ...

# %%
import xgboost as xgb

# Criando a matriz de dados DMatrix para o XGBoost
#dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Definindo os parâmetros do XGBoost para classificação binária
params = {
    'objective': 'binary:logistic',  # Classificação binária
    'max_depth': 6,  # Profundidade máxima da árvore
    'eta': 0.1,  # Taxa de aprendizado
    'eval_metric': 'logloss'  # Métrica de avaliação para classificação binária
}

# Treinando o modelo
evallist = [(dtrain, 'train'), (dtest, 'test')]
num_round = 100
bst = xgb.train(params, dtrain, num_round, evallist, early_stopping_rounds=10)

# Fazendo previsões (como probabilidades)
y_pred_prob = bst.predict(dtest)

# Convertendo as probabilidades em classes 0 ou 1
y_pred = [1 if pred > 0.5 else 0 for pred in y_pred_prob]

# Calculando a acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9516\1766254515.py in ?()
#       1 import xgboost as xgb
#       2
#       3 # Criando a matriz de dados DMatrix para o XGBoost
#       4 #dtrain = xgb.DMatrix(X_train, label=y_train)
# ----> 5 dtest = xgb.DMatrix(X_test, label=y_test)
#       6
#       7 # Definindo os parâmetros do XGBoost para classificação binária
#       8 params = {
#
# c:\Users\henri\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# ...

# %% [markdown]
# # Test dataset

# %%
df_test = pd.read_csv('./test.csv')

# %%
df_test = pd.get_dummies(df_test, columns=cat_cols).astype(int)

# %%
df_test[cont_cols] = scaler.transform(df_test[cont_cols])

# %%
df_test['loan_status'] = model.predict(df_test[variables])

# %%
#df_test[['id', 'loan_status']].to_parquet('./result_v1.parquet') # -> Logistic Regression w/o tunning and ft engineering (0.72364)
